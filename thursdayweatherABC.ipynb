# %%
import json
import urllib
import pandas as pd
import pickle
import datetime as dt

import json
import urllib
import pandas as pd
import pickle
import datetime as dt
from pandas import DataFrame, Series

url = 'http://datapoint.metoffice.gov.uk/public/data/val/wxfcs/all/json/352409?res=3hourly&key=8057bc82-1b58-4b7d-a54e-c7d275935300'
response = urllib.urlopen(url)
data = json.load(response)

with open('C:\Git\WeatherProject\Data\incomingData', 'rb') as p1:
    frame = pickle.load(p1)

origin = data.get('SiteRep', 'none').get('DV', 'none').get('dataDate', 'none')
y = int(origin[0:4])
m = int(origin[5:7])
d = int(origin[8:10])
h = int(origin[11:13])
origin = dt.datetime(y,m,d,h,0,0)
period = data.get('SiteRep', 'none').get('DV', 'none').get('Location').get('Period', 'none')
inctime = dt.datetime(y,m,d,h-3,0,0)
listy = []
for i in period:
    rep = i.get('Rep')
    for j in rep:
        inctime += dt.timedelta(hours = 3)
        listy = [inctime, origin, j.get('$'), j.get('D'), j.get('F'), j.get('G'), j.get('H'), j.get('Pp'), j.get('S'), j.get('T'), j.get('U'), j.get('V'), j.get('W')]
        frame = frame.append(Series(listy, index = ['Forecast Time','origin','UTC', 'Wind Direction', 'Degrees Celsius', 'Wind Gust (MPH)', 'Humidity', 'Precipitation', 'Wind Speed', 'Screen Temp', 'UV index', 'Visibility', 'Weather']), ignore_index = True)

with open('C:\Git\WeatherProject\Data\incomingData', 'wb') as p2:
    pickle.dump(frame, p2)

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Student25\\Desktop\\Met project'

# %%
frame
# Out:
#           Forecast Time              origin   UTC Wind Direction  \
# 0   2016-12-06 16:00:00 2016-12-06 16:00:00   720            SSE
# 1   2016-12-06 19:00:00 2016-12-06 16:00:00   900              S
# 2   2016-12-06 22:00:00 2016-12-06 16:00:00  1080            SSW
# 3   2016-12-07 01:00:00 2016-12-06 16:00:00  1260            SSW
# 4   2016-12-07 04:00:00 2016-12-06 16:00:00     0            SSW
# 5   2016-12-07 07:00:00 2016-12-06 16:00:00   180            SSW
# 6   2016-12-07 10:00:00 2016-12-06 16:00:00   360            SSW
# 7   2016-12-07 13:00:00 2016-12-06 16:00:00   540             SW
# 8   2016-12-07 16:00:00 2016-12-06 16:00:00   720            SSW
# 9   2016-12-07 19:00:00 2016-12-06 16:00:00   900            SSW
# 10  2016-12-07 22:00:00 2016-12-06 16:00:00  1080             SW
# 11  2016-12-08 01:00:00 2016-12-06 16:00:00  1260             SW
# 12  2016-12-08 04:00:00 2016-12-06 16:00:00     0             SW
# 13  2016-12-08 07:00:00 2016-12-06 16:00:00   180             SW
# 14  2016-12-08 10:00:00 2016-12-06 16:00:00   360             SW
# 15  2016-12-08 13:00:00 2016-12-06 16:00:00   540             SW
# 16  2016-12-08 16:00:00 2016-12-06 16:00:00   720             SW
# 17  2016-12-08 19:00:00 2016-12-06 16:00:00   900             SW
# 18  2016-12-08 22:00:00 2016-12-06 16:00:00  1080             SW
# 19  2016-12-09 01:00:00 2016-12-06 16:00:00  1260             SW
# 20  2016-12-09 04:00:00 2016-12-06 16:00:00     0             SW
# 21  2016-12-09 07:00:00 2016-12-06 16:00:00   180            SSW
# 22  2016-12-09 10:00:00 2016-12-06 16:00:00   360            SSW
# 23  2016-12-09 13:00:00 2016-12-06 16:00:00   540            SSW
# 24  2016-12-09 16:00:00 2016-12-06 16:00:00   720            SSW
# 23                9              18       94             7          9
# 24               10              20       88             7         11
# 25                9              18       88             7          9
# 26                8              20       92             9         11
# 27                8              22       92            15         11
# 28                9              22       91            13         11
# 29               10              22       91            17         11
# ..              ...             ...      ...           ...        ...
# 630               3              22       83             9         11
# 631               4              20       85            48          9
# 632               4              18       68            12          9
# 633               3              18       60             1          9
# 634               1              16       68             0          7
# 635              -1              16       74             0          7
# 636              -2              16       79             0          7
# 637              -2              11       83             0          4
# 638              -2               7       85             0          4
# 639              -2               4       88             0          2
# 640               1               4       80             0          2
# 641               2               4       81             0          2
# 642              -1               4       89             1          2
# 643              -2               7       92             4          4
# 644              -1               7       92             6          4
# 645              -2               9       89             6          4
# 646              -1              11       85             4          7
# 647              -1              13       85             5          7
# 648               3              16       77             5          9
# 649               3              18       78            42          9
# 650               2              20       87            60         11
# 651               3              22       90            50         11
# 652               4              18       92            20          9
# 653               5              16       95            18          9
# 654               6              13       95            15          7
# 655               7              13       94             9          7
# 656               8              16       91             9          7
# 657               8              13       90             9          7
# 658               7              13       89             5          7
# 659               6              11       91             5          4
#
#     Screen Temp UV index Visibility Weather Day/Night
# 0             8        1         PO       5       NaN
# 1            10        1         MO       8       NaN
# 2             9        0         MO       8       NaN
# 3             9        0         MO       8       NaN
# 4             9        0         MO       8       NaN
# 5             9        0         MO       8       NaN
# 6             9        0         MO       8       NaN
# 7            10        1         MO       8       NaN
# 8            11        1         MO       7       NaN
# 9            11        1         MO       7       NaN
# 10           10        0         MO       7       NaN
# 11           10        0         MO       7       NaN
# 12           11        0         GO       7       NaN
# 13           11        0         MO       8       NaN
# 14           11        0         MO       8       NaN
# 15           11        1         MO       8       NaN
# 16           12        1         GO       8       NaN
# 17           13        1         MO       8       NaN
# 18           12        0         MO       8       NaN
# 19           12        0         GO       8       NaN
# 20           12        0         GO       8       NaN
# 21           12        0         GO       8       NaN
# 22           11        0         GO       8       NaN
# 23           11        1         GO       7       NaN
# 24           12        1         GO       7       NaN
# 25           11        1         VG       7       NaN
# 26           10        0         GO       7       NaN
# 27           10        0         GO       8       NaN
# 28           11        0         GO       7       NaN
# 29           12        0         GO       8       NaN
# ..          ...      ...        ...     ...       ...
# 630           6        0         VG       7       NaN
# 631           7        1         GO      12       NaN
# 632           7        1         VG       7       NaN
# 633           6        1         VG       1       NaN
# 634           4        0         VG       0       NaN
# 635           2        0         VG       0       NaN
# 636           1        0         VG       0       NaN
# 637           0        0         GO       0       NaN
# 638           0        0         GO       0       NaN
# 639           0        1         GO       1       NaN
# 640           2        1         GO       1       NaN
# 641           4        1         GO       1       NaN
# 642           1        0         GO       2       NaN
# 643           0        0         GO       7       NaN
# 644           1        0         MO       7       NaN
# 645           1        0         GO       7       NaN
# 646           2        0         GO       2       NaN
# 647           2        1         GO       7       NaN
# 648           5        1         GO       7       NaN
# 649           6        1         MO      12       NaN
# 650           6        0         MO      12       NaN
# 651           6        0         MO      12       NaN
# 652           7        0         GO       8       NaN
# 653           8        0         GO       8       NaN
# 654           8        0         GO       8       NaN
# 655           8        1         GO       7       NaN
# 656           9        1         GO       8       NaN
# 657           9        1         GO       8       NaN
# 658           8        0         GO       7       NaN
# 659           8        0         GO       7       NaN
#
# [660 rows x 14 columns]

# %%
import plotly

# %%
import numpy as np
